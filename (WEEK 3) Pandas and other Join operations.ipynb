# %% [markdown]
# Suppose, we have an example as such

# %%
import pandas as pd

df = pd.DataFrame([{'Name': 'Chris', 'Item Purchased': 'Sponge', 'Cost': 22.50},
                   {'Name': 'Kevyn', 'Item Purchased': 'Kitty Litter', 'Cost': 2.50},
                   {'Name': 'Filip', 'Item Purchased': 'Spoon', 'Cost': 5.00}],
                  index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5         Sponge  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0          Spoon  Filip

# %%
df['Sex']=['Male','Male','Female']
df
# Out:
#          Cost Item Purchased   Name     Sex
# Store 1  22.5         Sponge  Chris    Male
# Store 1   2.5   Kitty Litter  Kevyn    Male
# Store 2   5.0          Spoon  Filip  Female

# %%
adf = df.reset_index()
#adf = pd.Series({0:''})
adf
# Out:
#      index  Cost Item Purchased   Name     Sex
# 0  Store 1  22.5         Sponge  Chris    Male
# 1  Store 1   2.5   Kitty Litter  Kevyn    Male
# 2  Store 2   5.0          Spoon  Filip  Female

# %% [markdown]
# ## Using outer and inner Joins
# Consider two different examples

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])
staff_df = staff_df.set_index('Name')
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])
student_df = student_df.set_index('Name')

print(staff_df)
print('----------------------------------------------------------------------')
print(student_df)
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader
# ----------------------------------------------------------------------
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %% [markdown]
# Now, we combine both the student and staff dataframes using different methods

# %%
andar = pd.merge(staff_df,student_df, how = 'inner', left_index = True, right_index = True)
print(andar)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
out = pd.merge(staff_df,student_df, how = 'outer', left_index = True, right_index = True)
print(out)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
out = pd.merge(staff_df, student_df, how = 'left', left_index = True, right_index = True)
print(out)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
# similarly, right join for obtaining all the details of right column
# how = right

# %%
ddl = pd.read_csv('student.csv')
print(ddl.head())
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR                    INSTURL  \
# 0     AL              www.aamu.edu/
# 1     AL                www.uab.edu
# 2     AL  www.amridgeuniversity.edu
# 3     AL                www.uah.edu
# 4     AL              www.alasu.edu
#
#                                               NPCURL  HCM2  PREDDEG  \
# 0      www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3
# 1           uab.studentaidcalculator.com/survey.aspx     0        3
# 2                   www2.amridgeuniversity.edu:9091/     0        3
# ...

# %%
ddl = pd.read_csv('train.csv')
#ddl = pd.read_csv('student.csv')
ddl
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
'''(ddl.where(ddl['Sex']=='male')
     .dropna()
     .set_index(['PassengerId']))'''
(ddl.where((ddl['Pclass']==2)&(ddl['SibSp']==1)).count())
print('---------------------------X----------------------------------')
# is working fine for a single condition
# Out:
# ---------------------------X----------------------------------
# PassengerId    577
# Survived       577
# Pclass         577
# Name           577
# Sex            577
# Age            453
# SibSp          577
# Parch          577
# Ticket         577
# Fare           577
# Cabin          107
# Embarked       577
# dtype: int64
# ---------------------------X----------------------------------
#      PassengerId  Survived  Pclass  \
# 6            7.0       0.0     1.0
# 21          22.0       1.0     2.0
# 23          24.0       1.0     1.0
# 27          28.0       0.0     1.0
# 54          55.0       0.0     1.0
# 62          63.0       0.0     1.0
# 75          76.0       0.0     3.0
# 92          93.0       0.0     1.0
# 96          97.0       0.0     1.0
# 97          98.0       1.0     1.0
# 102        103.0       0.0     1.0
# 110        111.0       0.0     1.0
# 118        119.0       0.0     1.0
# 124        125.0       0.0     1.0
# 137        138.0       0.0     1.0
# ...

# %% [markdown]
# ## Be extra coutious using where command and dropna()
# See the comments for details

# %%
# NOTE : if u use the dropna(), ANY COLUMN having a NaN value is rejected, keep this in mind in future

(ddl.where(ddl['Sex']=='male').count())
#print('---------------------------X----------------------------------')

# note the no of rows here... 577 rows
# Out:
# PassengerId    577
# Survived       577
# Pclass         577
# Name           577
# Sex            577
# Age            453
# SibSp          577
# Parch          577
# Ticket         577
# Fare           577
# Cabin          107
# Embarked       577
# dtype: int64

# %%
#however, compare this with... ONLY 95 rows

(ddl.where(ddl['Sex']=='male').dropna())
#print('---------------------------X----------------------------------')
# Out:
#      PassengerId  Survived  Pclass  \
# 6            7.0       0.0     1.0
# 21          22.0       1.0     2.0
# 23          24.0       1.0     1.0
# 27          28.0       0.0     1.0
# 54          55.0       0.0     1.0
# 62          63.0       0.0     1.0
# 75          76.0       0.0     3.0
# 92          93.0       0.0     1.0
# 96          97.0       0.0     1.0
# 97          98.0       1.0     1.0
# 102        103.0       0.0     1.0
# 110        111.0       0.0     1.0
# 118        119.0       0.0     1.0
# 124        125.0       0.0     1.0
# 137        138.0       0.0     1.0
# 139        140.0       0.0     1.0
# 148        149.0       0.0     2.0
# 170        171.0       0.0     1.0
# 174        175.0       0.0     1.0
# 183        184.0       1.0     2.0
# 193        194.0       1.0     2.0
# 209        210.0       1.0     1.0
# 224        225.0       1.0     1.0
# 245        246.0       0.0     1.0
# 248        249.0       1.0     1.0
# ...

# %% [markdown]
# ## Using Group By clause

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
c1=c2=c3=c1cunt=c2cunt=c3cunt=0
'''for person in df['PassengerId']:
    if(df.where(df['Pclass']==1)):
        cl1 = cl1 + df['Age']
    elif(df.where(df['Pclass']==2)):
        cl2 = cl2 + df['Age']
    else:
        cl3 = cl3 + df['Age']
        
print("Class 1 ", cl1)
print("Class 2 ", cl2)
print("Class 3 ", cl3)

This one didn't work
'''

# DROPPING ALL ROWS HAVING NaN values
df = df.dropna()
cunt = df['PassengerId'].count()
for i in range(cunt):
    d = df.iloc[i].dropna()
    if(d['Pclass']==1):
        c1 =c1+d['Age']
        c1cunt+=1
    elif(d['Pclass']==2):
        c2 = c2+d['Age']
        c2cunt+=1
    else:
        c3 = c3+d['Age']
        c3cunt+=1

        
#d = df.iloc[1]
#print(d['Age'])

#print((df.iloc[1]['Age']+df.iloc[2]['Age'])/5)



print("Class 1 Average = ", (c1/c1cunt))

print("Class 2 Average = ", (c2/c2cunt))   

print("Class 3 Average = ", (c3/c3cunt))   

#Obviously, after using the dropna command, see the number of rows decreased
print((c1cunt+c2cunt+c3cunt), "rows")
# Out:
# Class 1 Average =  37.5912658228
# Class 2 Average =  25.2666666667
# Class 3 Average =  21.0
# 183 rows
